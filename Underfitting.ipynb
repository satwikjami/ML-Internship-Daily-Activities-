# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv(r"C:\Users\user\underfitting_dataset.csv")
df
# Out:
#     Study_Hours  Marks
# 0             1      1
# 1             1      3
# 2             1      2
# 3             2      1
# 4             2      4
# 5             2      3
# 6             3      2
# 7             3      5
# 8             3      4
# 9             4      2
# 10            4      6
# 11            4      5
# 12            5      3
# 13            5      7
# 14            5      6
# 15            6      4
# 16            6      8
# 17            6      7
# 18            7      5
# 19            7      9
# 20            7      8
# 21            8      6
# 22            8     10
# 23            8      9
# 24            9      7
# 25            9     11
# 26            9     10
# 27           10      8
# 28           10     12
# 29           10     11

# %%
X = df[["Study_Hours"]]
Y = df["Marks"]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4)
X_train
# Out:
#     Study_Hours
# 11            4
# 12            5
# 22            8
# 4             2
# 25            9
# 7             3
# 0             1
# 3             2
# 18            7
# 10            4
# 5             2
# 19            7
# 8             3
# 28           10
# 21            8
# 14            5
# 2             1
# 29           10

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_train_pred = model.predict(X_train)
Y_test_pred = model.predict(X_test)

# %%
Y_train_pred
# Out:
# array([ 4.70072489,  5.72109078,  8.78218847,  2.6599931 ,  9.80255437,
#         3.68035899,  1.6396272 ,  2.6599931 ,  7.76182258,  4.70072489,
#         2.6599931 ,  7.76182258,  3.68035899, 10.82292026,  8.78218847,
#         5.72109078,  1.6396272 , 10.82292026])

# %%
train_mse = mean_squared_error(Y_train, Y_train_pred)
test_mse = mean_squared_error(Y_test, Y_test_pred)

# %%
print("Training MSE:", train_mse)
print("Testing MSE:", test_mse)
# Out:
# Training MSE: 2.085797568365743
# Testing MSE: 3.228037481153555

# %%
plt.figure()
plt.scatter(X,Y)
plt.plot(X, model.predict(X))
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Linear Regression Model")
plt.show()

# %%
residuals = Y_test - Y_test_pred
residuals
# Out:
# 26    0.197446
# 17    0.258543
# 9    -2.700725
# 23    0.217812
# 1     1.360373
# 15   -2.741457
# 13    1.278909
# 16    1.258543
# 6    -1.680359
# 27   -2.822920
# 24   -2.802554
# 20    0.238177
# Name: Marks, dtype: float64

# %%
plt.figure()
plt.scatter(X_test,residuals)
plt.axhline(0)
plt.xlabel("Study Hours (Test)")
plt.ylabel("Residuals")
plt.title("Residuals Plot (Test Data)")
plt.show()
